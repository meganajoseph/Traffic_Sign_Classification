# %% [markdown]
# <a href="https://colab.research.google.com/github/meganajoseph/Traffic_Sign_Classification/blob/main/math_250_traffic_sign_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imports
import kagglehub
import os
from kaggle.api.kaggle_api_extended import KaggleApi
from google.colab import userdata

# %%
# get secrets
os.environ['KAGGLE_API_TOKEN'] = userdata.get('KAGGLE_API_TOKEN')

# %%
api = KaggleApi()
api.authenticate()

# Download and extract
api.dataset_download_files('omkarnadkarni/lisa-traffic-sign', path='data', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/omkarnadkarni/lisa-traffic-sign
